# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Data

# %%
import pandas as pd
dataset = pd.read_csv(r"C:\Users\sulta\OneDrive\Desktop\superstore\sample data superstore.csv", encoding='latin1')

# %%
dataset.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
dataset.shape
# Out:
# (9994, 21)

# %% [markdown]
# # Check for missing values

# %%
 dataset.isnull()
# Out:
#       Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0      False     False       False      False      False        False
# 1      False     False       False      False      False        False
# 2      False     False       False      False      False        False
# 3      False     False       False      False      False        False
# 4      False     False       False      False      False        False
# ...      ...       ...         ...        ...        ...          ...
# 9989   False     False       False      False      False        False
# 9990   False     False       False      False      False        False
# 9991   False     False       False      False      False        False
# 9992   False     False       False      False      False        False
# 9993   False     False       False      False      False        False
#
#       Customer Name  Segment  Country   City  ...  Postal Code  Region  \
# ...

# %% [markdown]
# # Sum of missing values per column

# %%
dataset.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# # Drop rows with missing values

# %%
dataset.dropna()
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %% [markdown]
# # Replace missing values with 0 (zero) if any

# %%
dataset.fillna(0)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
import pandas as pd

# Assuming df is your DataFrame
# Replace 'Order Date' and 'Ship Date' with the actual column names from your DataFrame
dataset['Order Date'] = pd.to_datetime(dataset['Order Date'])
dataset['Ship Date'] = pd.to_datetime(dataset['Ship Date'])

# To confirm the conversion
print(dataset.dtypes)
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
dataset['Order Date'].dt.year
# Out:
# 0       2016
# 1       2016
# 2       2016
# 3       2015
# 4       2015
#         ...
# 9989    2014
# 9990    2017
# 9991    2017
# 9992    2017
# 9993    2017
# Name: Order Date, Length: 9994, dtype: int32

# %%
dataset['Order year'] = dataset['Order Date'].dt.year

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
dataset['Order year'].value_counts()
# Out:
# Order year
# 2017    3312
# 2016    2587
# 2015    2102
# 2014    1993
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,5))
sns.countplot(x="Order year",data=dataset,hue="Order year")
plt.show()

# %% [markdown]
# # Product Category

# %%
dataset['Sub-Category'].value_counts()
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(17,5))
import seaborn as sns
plt.title("Count of Sub-Category")
plt.savefig("Count of Sub-Category.jpg")
sns.countplot(x="Sub-Category",data=dataset,hue="Sub-Category")
plt.show()

# %%
dataset['Category'].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,5))
import seaborn as sns
plt.title("Category")
sns.countplot(x="Category",data=dataset,hue="Category")
plt.show()

# %%
import pandas as pd
dataset = pd.read_csv(r"C:\Users\sulta\OneDrive\Desktop\superstore\sample data superstore.csv", encoding='latin1')
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
sns.countplot(x="Category",data=dataset[dataset["Category"]=="Office Supplies"],hue="Sub-Category")
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.countplot(x="Category",data=dataset[dataset["Category"]=="Furniture"],hue="Sub-Category")
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.countplot(x="Category",data=dataset[dataset["Category"]=="Technology"],hue="Sub-Category")
plt.show()

# %% [markdown]
# # Shipping Mode

# %%
dataset['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
x = dataset['Ship Mode'].value_counts().index
y = dataset['Ship Mode'].value_counts().values

# %%
plt.figure(figsize=(5,5))
plt.pie(y,labels=x,startangle = 60,autopct="%0.2f%%")
plt.legend(loc=2)
plt.show()

# %%
plt.figure(figsize=(7,4))
sns.countplot(x="Ship Mode",data=dataset,hue="Category")
plt.show()

# %% [markdown]
# # Customer Segment

# %%
plt.figure(figsize=(5,5))
sns.countplot(x="Segment",data=dataset,hue="Segment")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
dataset = pd.read_csv(r"C:\Users\sulta\OneDrive\Desktop\superstore\sample data superstore.csv", encoding='latin1')
import seaborn as sns
plt.figure(figsize=(5,5))
plt.title("Profit By Category")
sns.barplot(x="Category",y="Profit",data=dataset,estimator='sum')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
dataset = pd.read_csv(r"C:\Users\sulta\OneDrive\Desktop\superstore\sample data superstore.csv", encoding='latin1')
import seaborn as sns
plt.figure(figsize=(18,6))
plt.title("Profit By Sub-Category")
sns.barplot(x="Sub-Category",y="Profit",data=dataset,estimator='sum',hue="Sub-Category")
plt.show()

# %% [markdown]
# # Sale by Region

# %%
dataset['Region'].value_counts()
# Out:
# Region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %% [markdown]
# # Yearly Sales by Region

# %%
import pandas as pd
dataset['Order Date'] = pd.to_datetime(dataset['Order Date'])
dataset['Year'] = dataset['Order Date'].dt.year
# Group by city and year, then calculate total sales
yearly_sales_by_region = dataset.groupby(['Region', 'Year'])['Sales'].sum().reset_index()
print(yearly_sales_by_region)
# Out:
#      Region  Year        Sales
# 0   Central  2014  103838.1646
# 1   Central  2015  102874.2220
# 2   Central  2016  147429.3760
# 3   Central  2017  147098.1282
# 4      East  2014  128680.4570
# 5      East  2015  156332.0570
# 6      East  2016  180685.8220
# 7      East  2017  213082.9040
# 8     South  2014  103845.8435
# 9     South  2015   71359.9805
# 10    South  2016   93610.2235
# 11    South  2017  122905.8575
# 12     West  2014  147883.0330
# 13     West  2015  139966.2495
# 14     West  2016  187480.1765
# 15     West  2017  250128.3655

# %% [markdown]
# # Sale by City

# %%
dataset['City'].value_counts()
# Out:
# City
# New York City      915
# Los Angeles        747
# Philadelphia       537
# San Francisco      510
# Seattle            428
#                   ...
# Glenview             1
# Missouri City        1
# Rochester Hills      1
# Palatine             1
# Manhattan            1
# Name: count, Length: 531, dtype: int64

# %% [markdown]
# # Yearly Sales by City

# %%
import pandas as pd
dataset['Order Date'] = pd.to_datetime(dataset['Order Date'])
dataset['Year'] = dataset['Order Date'].dt.year
# Group by city and year, then calculate total sales
yearly_sales_by_city = dataset.groupby(['City', 'Year'])['Sales'].sum().reset_index()
print(yearly_sales_by_city)
# Out:
#           City  Year    Sales
# 0     Aberdeen  2017   25.500
# 1      Abilene  2017    1.392
# 2        Akron  2014  170.910
# 3        Akron  2015  427.548
# 4        Akron  2016  804.228
# ...        ...   ...      ...
# 1208      York  2016  714.498
# 1209      York  2017  103.480
# 1210   Yucaipa  2015   50.800
# 1211      Yuma  2016  240.880
# 1212      Yuma  2017  599.985
#
# [1213 rows x 3 columns]
